# %%
import math

# %%
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
def multiply(a,b):
    return a*b
def divide(a,b):
    return a/b
def sqrt(a):
    result=math.sqrt(a)
    return result
def exp(a):  #here we're performing the square of a
    return a**2
def sin(x):
    result=math.sin(x)
    return result
def cos(x):
    result=math.cos(x)
    return result
def tan(x):
    result=math.tan(x)
    return result

print("""
Choose the Number from the following operations
1- Addition(x,y)
2- Substraction(x,y)
3- Multiplication(x,y)
4- Divide(x,y)
5- Square(x)
6- Square root(x)
7- Sin(x)
8- Cos(x)
9- Tan(x)""")
op= int(input("Enter the linked NUMBER of the Operation you would like to perform: "))


while op<10:
    if op==1:
        print("Enter the Numbers")
        x1= int(input("enter x"))
        y1= int(input("enter y"))
        res1=add(x1,y1)
        print("Addition: ", res1)
        
    elif op==2:
        print("Enter the Numbers")
        x2= int(input("enter x"))
        y2= int(input("enter y"))
        res2=sub(x2,y2)
        print("Substraction: ", res2)

    elif op==3:
        print("Enter the Numbers")
        x3= int(input("enter x"))
        y3= int(input("enter y"))
        res2=mul(x3,y3)
        print("Multiplication: ", res3)
        
    elif op==4:
        print("Enter the Numbers")
        x4= int(input("enter x"))
        y4= int(input("enter y"))
        res4=divide(x4,y4)
        print("Divide: ", res4)
    
    elif op==5:
        print("Enter the Numbers")
        x5= int(input("enter x"))
        res5=exp(x5)
        print("Square: ", res5)

    elif op==6:
        print("Enter the Numbers")
        x6= int(input("enter x"))
        res6=exp(x6)
        print("Square root: ", res6)        
        

    elif op==7:
        print("Enter the Numbers")
        x7= int(input("enter x"))
        res7=sin(x7)
        print("Sin(x): ", res7)
        
        
    elif op==8:
        print("Enter the Numbers")
        x8= int(input("enter x"))
        res8=sin(x8)
        print("Cos(x): ", res8)        
        
    elif op==9:
        print("Enter the Numbers")
        x9= int(input("enter x"))
        res9=sin(x9)
        print("Tan(x): ", res9)        
        
    else:
        print("Choose another Option")
        
    
    new=int(input("Do you wish to continue the Operations - (YES-1), (NO-0)"))
    
    if new==1:
        op=int (input("enter Operation"))
            
    elif new==0:
        print("Thanks for using our Service of the Scientific Calculator")
        break
# Out:
# Choose the Number from the following operations
# 1- Addition(x,y)
# 2- Substraction(x,y)
# 3- Multiplication(x,y)
# 4- Divide(x,y)
# 5- Square(x)
# 6- Square root(x)
# 7- Sin(x)
# 8- Cos(x)
# 9- Tan(x)
# Enter the linked NUMBER of the Operation you would like to perform: 1
# Enter the Numbers
# enter x123
# enter y23
# Addition:  146
# Do you wish to continue the Operations - (YES-1), (NO-0)0
# Thanks for using our Service of the Scientific Calculator
